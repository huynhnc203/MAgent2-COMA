# %%
# !ls
# Out:
#  models          main.py          requirements.txt video
# README.md        marl_src         torch_model.py
# assets           metrics          train.py
# magent_lab.ipynb red.pt           ver-0.19

# %%
# !python3 train.py --config=coma.yaml --save="coma_0"
# Out:
# Global Config: {'n_agents': 81, 'n_actions': 21, 'buffer_size': 40, 'num_actions': 21, 'lr': 0.001, 'seq_len': 300, 'batch_size': 10, 'gamma': 0.69, 'theta_decay': 0.01, 'epsilon': '1e-8', 'tau': 0.005, 'target_update_frequency': 200, 'training_frequency': 100, 'min_exploration': 0.3, 'max_exploration': 0.7, 'save_frequency': 10, 'rnn_hidden_dim': 512, 'obs_dim': 845, 'state_dim': 10125, 'lambda_entropy': 0.01, 'hidden_dim': 512, 'end_game_reward': 100}
# Environment Config: {'max_cycles': 300, 'step_reward': 0.01, 'dead_penalty': -0.5, 'attack_penalty': -0.1, 'attack_opponent_reward': 2}
# Training Config: {'device': 'cpu', 'episodes': 500}
# Model: coma
# Episode: 0 | Duration: 17.47s
# Episode: 1 | Duration: 16.83s
# Episode: 2 | Duration: 16.09s
# Episode: 3 | Duration: 16.56s
# Episode: 4 | Duration: 16.28s
# Episode: 5 | Duration: 19.46s
# Episode: 6 | Duration: 15.75s
# Episode: 7 | Duration: 14.14s
# Episode: 8 | Duration: 15.08s
# torch.Size([10, 81, 512])
# ...
